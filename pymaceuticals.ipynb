# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_data_complete = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
mouse_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_count = mouse_data_complete['Mouse ID'].nunique()
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_id = mouse_data_complete.loc[mouse_data_complete.duplicated(subset=['Mouse ID', 'Timepoint']), 'Mouse ID'].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Create a dataframe that has all the data for the duplicate mouse ID. 
duplicate_data = mouse_data_complete[mouse_data_complete['Mouse ID'] == 'g989']
duplicate_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = mouse_data_complete[mouse_data_complete['Mouse ID'].isin(duplicate_mouse_id)==False]
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_mouse_data['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean_tumor_vol = clean_mouse_data.groupby(["Drug Regimen"])['Tumor Volume (mm3)'].mean()
median_tumor_vol = clean_mouse_data.groupby(["Drug Regimen"])['Tumor Volume (mm3)'].median()
variance_tumor_vol = clean_mouse_data.groupby(["Drug Regimen"])['Tumor Volume (mm3)'].var()
std_tumor_vol = clean_mouse_data.groupby(["Drug Regimen"])['Tumor Volume (mm3)'].std()
sem_tumor_vol = clean_mouse_data.groupby(["Drug Regimen"])['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
tumor_vol_summary = pd.DataFrame({"Mean Tumor Volume": mean_tumor_vol, "Median Tumor Volume": median_tumor_vol,
                                  "Tumor Volume Variance": variance_tumor_vol, "Tumor Volume Std. Dev.": std_tumor_vol,
                                  "Tumor Volume Std. Err.": sem_tumor_vol})
tumor_vol_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
tumor_summary_stats = clean_mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(['mean', 'median', 'var', 'std', 'sem'])
tumor_summary_stats
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
count_by_regimen = clean_mouse_data["Drug Regimen"].value_counts()

# Create the bar plot
count_by_regimen.plot(kind='bar', figsize=(10, 6))

# Set the title and labels
plt.title("# of Observed Mouse Timepoints Per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

# Display the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
count_by_regimen2 = clean_mouse_data["Drug Regimen"].value_counts()

# Get the unique drug regimens and their counts
regimens2 = count_by_regimen2.index
counts2 = count_by_regimen2.values

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(regimens2, counts2)

# Set the title and labels
plt.title("# of Observed Mouse Timepoints Per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

# Rotate x-axis labels if needed
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_dist = clean_mouse_data["Sex"].value_counts()

# Create the pie plot
gender_dist.plot(kind='pie', figsize=(10, 6), autopct='%1.1f%%')

# Set the title and labels
plt.title("Distribution of Female and Male Mice")
plt.ylabel("Sex")

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_dist2 = clean_mouse_data["Sex"].value_counts()

# Get the unique drug regimens and their counts
sex2 = gender_dist2.index
counts2 = gender_dist2.values

# Create the pie plot
plt.figure(figsize=(10, 6))
plt.pie(counts, labels=sex, autopct='%1.1f%%')

# Set the title and labels
plt.title("Distribution of Female and Male Mice")
plt.ylabel("Sex")

# Rotate x-axis labels if needed
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = clean_mouse_data.groupby(["Mouse ID"])['Timepoint'].max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
last_tumor_volume = pd.merge(last_timepoint, clean_mouse_data, on=['Mouse ID', 'Timepoint'], how = "left")

print(last_tumor_volume[['Mouse ID', 'Drug Regimen', 'Tumor Volume (mm3)', 'Timepoint']])
# Out:
#     Mouse ID Drug Regimen  Tumor Volume (mm3)  Timepoint
# 0       a203    Infubinol           67.973419         45
# 1       a251    Infubinol           65.525743         45
# 2       a262      Placebo           70.717621         45
# 3       a275     Ceftamin           62.999356         45
# 4       a366     Stelasyn           63.440686         30
# ..       ...          ...                 ...        ...
# 243     z435     Propriva           48.710661         10
# 244     z578     Ramicane           30.638696         45
# 245     z581    Infubinol           62.754451         45
# 246     z795     Naftisol           65.741070         45
# 247     z969     Naftisol           73.867845         45
#
# [248 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_data = []

# Loop through each treatment
for treatment in treatments:
   
    # Locate the rows for the current treatment and get the tumor volumes
    treatment_data = last_tumor_volume.loc[last_tumor_volume['Drug Regimen'] == treatment, 'Tumor Volume (mm3)']
    
    # Add the tumor volumes to the list
    tumor_volume_data.append(treatment_data)
    
    # Calculate quartiles, IQR, and bounds for potential outliers
    quartiles = treatment_data.quantile([0.25, 0.5, 0.75])
    lower_quartile = quartiles[0.25]
    upper_quartile = quartiles[0.75]
    iqr = upper_quartile - lower_quartile
    lower_bound = lower_quartile - (1.5 * iqr)
    upper_bound = upper_quartile + (1.5 * iqr)
    
    # Determine outliers using upper and lower bounds
    outliers = treatment_data[(treatment_data < lower_bound) | (treatment_data > upper_bound)]
    
    print(f"{treatment}'s potential treatment: Number of potential outliers: {outliers}")
# Out:
# Capomulin's potential treatment: Number of potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential treatment: Number of potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential treatment: Number of potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential treatment: Number of potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_title('Treatments')
ax1.set_ylabel('Final Tumor Volume (mm3)')

# Pass the tumor volume data for each treatment group to the boxplot function
ax1.boxplot(tumor_volume_data, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 10})

# Set the x-axis tick labels to the treatment names
ax1.set_xticklabels(treatments)

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse (l509) treated with Capomulin

# Filter the data for mouse l509 treated with Capomulin
mouse_l509 = clean_mouse_data.loc[(clean_mouse_data['Mouse ID'] == 'l509') & (clean_mouse_data['Drug Regimen'] == 'Capomulin')]

# Extract the time point and tumor volume data for the mouse
timepoints = mouse_l509['Timepoint']
tumor_volume = mouse_l509['Tumor Volume (mm3)']

# Generate the line plot
plt.plot(timepoints, tumor_volume, color="blue")

plt.title("Capomulin treatment of mouse l509")
plt.xlabel("Timepoint (days)")
plt.xticks(np.arange(min(timepoints), max(timepoints) + 1, 10))
plt.ylabel("Tumor Volume (mm3)")

# Display the plot
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# Filter the data for the Capomulin Drug Regimen
capomulin_regimen = clean_mouse_data.loc[clean_mouse_data['Drug Regimen'] == 'Capomulin']

# Calculate the mean tumor volume for each weight
mean_capomulin_tumor_volume = capomulin_regimen.groupby(['Mouse ID']).mean()

# Create a scatter plot
plt.scatter(mean_capomulin_tumor_volume["Weight (g)"], mean_capomulin_tumor_volume['Tumor Volume (mm3)'])

# Set the axis labels and title
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Mouse Weight Vs. Average Observed Tumor Volume (Capomulin regimen)")

# Display the plot
plt.show()
# Out:
# C:\Users\16133\AppData\Local\Temp\ipykernel_4784\1700662092.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_capomulin_tumor_volume = capomulin_regimen.groupby(['Mouse ID']).mean()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
